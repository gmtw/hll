# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
# %matplotlib inline

# %%
data_lax = np.loadtxt('euler_lax-04.dat')

# %%
data_hll = np.loadtxt('../hll2/euler_lax-02.dat')

# %%
os.listdir()
# Out:
# ['euler_lax-03.dat',
#  'euler_solve_hll',
#  'euler_lax-06.dat',
#  'euler_solve_hll.f90',
#  'euler_lax-07.dat',
#  'euler_lax-04.dat',
#  'Visualización HLL.ipynb',
#  'prueba.f90',
#  'prueba',
#  'euler_lax-08.dat',
#  'euler_lax-09.dat',
#  'euler_lax-00.dat',
#  'euler_lax-05.dat',
#  'globals.mod',
#  'rho.sc',
#  '.gitignore',
#  'euler_lax-01.dat',
#  '.git',
#  'euler_lax-02.dat',
#  '.ipynb_checkpoints']

# %%
plt.figure(figsize=(25,16))


plt.subplot(2,2,1)
#plt.plot(data[:,0], data[:,1], 'r--')
plt.scatter(data_lax[:,0], data_lax[:,1],marker='*')
plt.scatter(data_hll[:,0], data_hll[:,1],marker='*')
plt.xlabel('Position', fontsize=20)
plt.ylabel('Density', fontsize=20)
plt.grid(True)

plt.subplot(2,2,2)
plt.scatter(data_lax[:,0], data_lax[:,2] )
plt.scatter(data_hll[:,0], data_hll[:,2])
plt.xlabel('Position', fontsize=20)
plt.ylabel('Velocity', fontsize=20)
plt.ylim(0,1.6)
plt.grid(True)

plt.subplot(2,2,3)
plt.scatter(data_lax[:,0], data_lax[:,3])
plt.scatter(data_hll[:,0], data_hll[:,3])
plt.xlabel('Position', fontsize=20)
plt.ylabel('Pressure', fontsize=20)
plt.grid(True)
